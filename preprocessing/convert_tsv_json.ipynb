# %%
###Mount data directory for MIMIC
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
###Read dataset
import pandas as pd
from pathlib import Path

###init dataset path
dataset_dir = Path('/content/gdrive/MyDrive/hackathon/mimic-ner/')
interim_directory = Path('/content/gdrive/MyDrive/hackathon/preprocessing/')

data_df = pd.read_csv(dataset_dir / "ner_test_flat.tsv", sep="\t")

print(data_df.columns)

###Convert JSON
data_df.to_json(interim_directory / "ner_test_flat.json", index=False)
# Out:
# Index(['note_ID,"text","ner_text","ner_type"'], dtype='object')

# %%
###Load JSON test
import json

with open("/content/gdrive/MyDrive/hackathon/preprocessing/ner_test_flat.json") as f:
  data_json = json.load(f)

###view
