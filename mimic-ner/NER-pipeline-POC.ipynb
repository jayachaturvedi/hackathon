# %%
# !pip install gliner
# Out:
# Collecting gliner
#   Downloading gliner-0.2.16-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gliner) (2.5.1+cu124)
# Requirement already satisfied: transformers>=4.38.2 in /usr/local/lib/python3.11/dist-packages (from gliner) (4.48.2)
# Requirement already satisfied: huggingface_hub>=0.21.4 in /usr/local/lib/python3.11/dist-packages (from gliner) (0.28.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gliner) (4.67.1)
# Collecting onnxruntime (from gliner)
#   Downloading onnxruntime-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from gliner) (0.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.4->gliner) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.4->gliner) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.4->gliner) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.4->gliner) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.4->gliner) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.4->gliner) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->gliner) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->gliner) (3.1.5)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->gliner)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->gliner)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->gliner)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->gliner)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->gliner)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->gliner)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->gliner)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->gliner)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->gliner)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->gliner) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->gliner) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->gliner)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->gliner) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->gliner) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->gliner) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.38.2->gliner) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.38.2->gliner) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.38.2->gliner) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.38.2->gliner) (0.5.2)
# Collecting coloredlogs (from onnxruntime->gliner)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime->gliner) (25.1.24)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime->gliner) (4.25.6)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->gliner)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->gliner) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.21.4->gliner) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.21.4->gliner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.21.4->gliner) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.21.4->gliner) (2025.1.31)
# Downloading gliner-0.2.16-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 39.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 41.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 27.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 70.4 MB/s eta 0:00:00
# Downloading onnxruntime-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 90.1 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.1 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, humanfriendly, nvidia-cusparse-cu12, nvidia-cudnn-cu12, coloredlogs, onnxruntime, nvidia-cusolver-cu12, gliner
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed coloredlogs-15.0.1 gliner-0.2.16 humanfriendly-10.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 onnxruntime-1.20.1

# %%
###Mount data directory
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
###Read dataset
import pandas as pd
from pathlib import Path

###init dataset path
dataset_dir = Path('/content/gdrive/MyDrive/HDRUK-2025/hackathon/')
interim_directory = Path('/content/gdrive/MyDrive/HDRUK-2025/')

cvd_df = pd.read_csv(dataset_dir / "cvd_note.csv")

column_names = cvd_df.columns
print(column_names)

###Give a placeholder ID for each text
cvd_df.columns.values[0] = 'note_ID'

print(cvd_df['note_ID'])
# Out:
# <ipython-input-9-f8f4a807b808>:9: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   cvd_df = pd.read_csv(dataset_dir / "cvd_note.csv")
# Index(['Unnamed: 0', 'row_id', 'subject_id', 'hadm_id', 'seq_num', 'icd9_code',
#        'row_id.1', 'subject_id.1', 'hadm_id.1', 'chartdate', 'charttime',
#        'storetime', 'category', 'description', 'cgid', 'iserror', 'text'],
#       dtype='object')
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 364074    364074
# 364075    364075
# 364076    364076
# 364077    364077
# 364078    364078
# Name: note_ID, Length: 364079, dtype: int64

# %%
###MIMIC headings
known_headings = [
    "Name:",
    "Unit No:",
    "Admission Date:",
    "Discharge Date:",
    "Date of Birth:",
    "Sex:",
    "Service:",
    "Allergies:",
    "Attending:",
    "Chief Complaint:",
    "History of Present Illness:",
    "Past Medical History:",
    "Social History:",
    "Family History:",
    "Physical Exam:",
    "Pathology:",
    "Brief Hospital Course:",
    "Medications on Admission:",
    "Discharge Medications:",
    "Discharge Disposition:",
    "Discharge Diagnosis:",
    "Discharge Condition:",
    "Discharge Instructions:",
    "Followup Instructions:",
    "Discharge:",
    "Pertinent Results:",
    "Studies:",
    "Pending Results:",
    "Transitional Issues:",
    "PAST SURGICAL HISTORY:",
    "ADMISSION PHYSICAL EXAM:",
    "DISCHARGE PHYSICAL EXAM:",
    "PERTINENT LABS:",
    "DISCHARGE LABS:",
    "MICROBIOLOGY:",
    "IMAGING:",
    "ACTIVE ISSUES:",
    "CHRONIC ISSUES:",
    "Review of Systems:",
    "Major Surgical or Invasive Procedure:",
    "ADMISSION CXR:",
    "FOLLOW UP CXR:",
    "VASCULAR SURGERY ADMISSION EXAM:",
    "ADMISSION LABS:",
    "DEATH EXAM:",
    "CXR:",
    "CXR ___:",
    "SECONDARY:",
    "LABS:",
    "HOSPITAL COURSE:" #JC added
]

# %%
###Splitting MIMIC notes by heading
import re
import numpy as np

print("Splitting notes and annotations based on subheadings...")

def extract_subsections(x):
    section_dict = {}
    # for heading in known_headings:
    for heading in headings_to_extract:
        #print(f"Extracting subsection for heading: {heading}")
        pattern = r"(^|\s\s+)" + re.escape(heading)

        if not re.search(pattern, x):
            continue

        match = re.search(pattern, x)

        start_index_extract = match.start()

        # find closest next section, starting from end of note
        next_section_index = len(x) - 1
        for next_heading in known_headings:
            if next_heading.__eq__(heading):
                continue

            pattern_next = r"(^|\s\s+)" + re.escape(next_heading)
            match_next = re.search(pattern_next, x)

            if not re.search(pattern_next, x):
                continue

            if next_section_index > match_next.start() > start_index_extract:
                next_section_index = match_next.start()

        # extract section between start and next section, store
        section_dict[heading] = [start_index_extract, next_section_index, x[start_index_extract:next_section_index]]

    return section_dict

########
### call it
########
headings_to_extract = [
    "History of Present Illness:",
    "Medications on Admission:",
    "Discharge Medications:"
]

# for each note_id, extract sections and save as [note_id | section | section_begin | section_end | section_type]
# do a subset
cvd_subset_df = cvd_df.head(100)

note_ids = cvd_subset_df["note_ID"].unique()

# subsections = []
subsection_texts = []
i=0
for note_id in note_ids:
    print(f"Extracting subsection for: {i}th note.")
    text = cvd_subset_df.loc[cvd_subset_df["note_ID"] == note_id, 'text'].item()
    subsections_dict = extract_subsections(text)

    subnote_text = ""

    for key in subsections_dict.keys():
        start_index = subsections_dict[key][0]
        end_index = subsections_dict[key][1]

        # concat the text and codes into single entry
        subnote_text = subnote_text + subsections_dict[key][2]

    # remove duplicate codes and descriptions TODO: optional
    subsection_texts.append(subnote_text.lstrip())
    i+=1

# bring subsection text into dataframe + add ids
notes_sections_df = pd.DataFrame(subsection_texts)
notes_sections_df.insert(0, "note_ID", note_ids)
notes_sections_df.columns = ['note_ID', 'text']

# remove rows where note did not contain subsections
drop_rows = notes_sections_df[notes_sections_df['text']==''].index
notes_sections_df.drop(drop_rows, inplace=True)

print(notes_sections_df.columns.values)
notes_sections_df.to_csv(interim_directory / "mimic_text_subsections.csv", index=False)

print("NOTES SECT:")
#print(notes_sections_df.iloc[0])
# Out:
# Splitting notes and annotations based on subheadings...
# Extracting subsection for: 0th note.
# Extracting subsection for: 1th note.
# Extracting subsection for: 2th note.
# Extracting subsection for: 3th note.
# Extracting subsection for: 4th note.
# Extracting subsection for: 5th note.
# Extracting subsection for: 6th note.
# Extracting subsection for: 7th note.
# Extracting subsection for: 8th note.
# Extracting subsection for: 9th note.
# Extracting subsection for: 10th note.
# Extracting subsection for: 11th note.
# Extracting subsection for: 12th note.
# Extracting subsection for: 13th note.
# Extracting subsection for: 14th note.
# Extracting subsection for: 15th note.
# Extracting subsection for: 16th note.
# Extracting subsection for: 17th note.
# Extracting subsection for: 18th note.
# Extracting subsection for: 19th note.
# Extracting subsection for: 20th note.
# Extracting subsection for: 21th note.
# Extracting subsection for: 22th note.
# Extracting subsection for: 23th note.
# Extracting subsection for: 24th note.
# Extracting subsection for: 25th note.
# Extracting subsection for: 26th note.
# Extracting subsection for: 27th note.
# Extracting subsection for: 28th note.
# Extracting subsection for: 29th note.
# Extracting subsection for: 30th note.
# Extracting subsection for: 31th note.
# Extracting subsection for: 32th note.
# Extracting subsection for: 33th note.
# Extracting subsection for: 34th note.
# Extracting subsection for: 35th note.
# Extracting subsection for: 36th note.
# Extracting subsection for: 37th note.
# Extracting subsection for: 38th note.
# Extracting subsection for: 39th note.
# Extracting subsection for: 40th note.
# Extracting subsection for: 41th note.
# Extracting subsection for: 42th note.
# Extracting subsection for: 43th note.
# Extracting subsection for: 44th note.
# Extracting subsection for: 45th note.
# Extracting subsection for: 46th note.
# Extracting subsection for: 47th note.
# Extracting subsection for: 48th note.
# Extracting subsection for: 49th note.
# Extracting subsection for: 50th note.
# Extracting subsection for: 51th note.
# Extracting subsection for: 52th note.
# Extracting subsection for: 53th note.
# Extracting subsection for: 54th note.
# Extracting subsection for: 55th note.
# Extracting subsection for: 56th note.
# Extracting subsection for: 57th note.
# Extracting subsection for: 58th note.
# Extracting subsection for: 59th note.
# Extracting subsection for: 60th note.
# Extracting subsection for: 61th note.
# Extracting subsection for: 62th note.
# Extracting subsection for: 63th note.
# Extracting subsection for: 64th note.
# Extracting subsection for: 65th note.
# Extracting subsection for: 66th note.
# Extracting subsection for: 67th note.
# Extracting subsection for: 68th note.
# Extracting subsection for: 69th note.
# Extracting subsection for: 70th note.
# Extracting subsection for: 71th note.
# Extracting subsection for: 72th note.
# Extracting subsection for: 73th note.
# Extracting subsection for: 74th note.
# Extracting subsection for: 75th note.
# Extracting subsection for: 76th note.
# Extracting subsection for: 77th note.
# Extracting subsection for: 78th note.
# Extracting subsection for: 79th note.
# Extracting subsection for: 80th note.
# Extracting subsection for: 81th note.
# Extracting subsection for: 82th note.
# Extracting subsection for: 83th note.
# Extracting subsection for: 84th note.
# Extracting subsection for: 85th note.
# Extracting subsection for: 86th note.
# Extracting subsection for: 87th note.
# Extracting subsection for: 88th note.
# Extracting subsection for: 89th note.
# Extracting subsection for: 90th note.
# Extracting subsection for: 91th note.
# Extracting subsection for: 92th note.
# Extracting subsection for: 93th note.
# Extracting subsection for: 94th note.
# Extracting subsection for: 95th note.
# Extracting subsection for: 96th note.
# Extracting subsection for: 97th note.
# Extracting subsection for: 98th note.
# Extracting subsection for: 99th note.
# ['note_ID' 'text']
# NOTES SECT:

# %%
###Initialize NER model
import torch

from gliner import GLiNER

#config = {'temperature': 0.0}

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

print("Initializing")
#model_path = "urchade/gliner_mediumv2.1"
model_path = "urchade/gliner_large_bio-v0.2"
model = GLiNER.from_pretrained(model_path, max_length=2000)
# Out:
# Initializing
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# gliner_config.json:   0%|          | 0.00/477 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.78G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/580 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/convert_slow_tokenizer.py:561: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
###Single line test

input_text = "Patient has biliary pancreatitis, without signs of RA. Reports chest pain after taking NSAIDs and fluoroxicillin. Blood results normal. Also has nausea."
labels = ["Disorder", "Symptom", "Medication"]

###Run NER
print("Running NER")
entities = model.predict_entities(input_text, labels, threshold=0.5)

for entity in entities:
    print(entity["text"], "=>", entity["label"])
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Running NER
# biliary pancreatitis => Disorder
# RA => Disorder
# chest pain => Symptom
# NSAIDs => Medication
# fluoroxicillin => Medication
# nausea => Symptom

# %%
###NER for each note + place in tabular format (based on label)

labels = ["Symptom", "Medication"]

print("Running NER")

NER_result_df = notes_sections_df.copy()

i=0

symptoms, medications = ([] for i in range(2))
for input_text in notes_sections_df['text']:
  entities = model.predict_entities(input_text, labels, threshold=0.5)

  print(entities)

  ## if only caring about unique - use sets, else use []
  symptoms_note, medications_note = (set() for i in range(2))
  for entity in entities:
    label = entity["label"]

    if label == "Symptom":
      symptoms_note.add(entity['text'].lower())
    elif label == "Medication":
      medications_note.add(entity['text'].lower())

  i+=1
  symptoms.append(str(symptoms_note))
  medications.append(str(medications_note))

NER_result_df["symptoms"] = symptoms
NER_result_df["medications"] = medications

NER_result_df.replace(r'^\s*$', np.nan, regex=True)

NER_result_df.to_csv(interim_directory / "ner_test.csv", index=False)
# Out:
# Running NER
# [{'start': 459, 'end': 465, 'text': 'fevers', 'label': 'Symptom', 'score': 0.8830780386924744}, {'start': 470, 'end': 480, 'text': 'ankle pain', 'label': 'Symptom', 'score': 0.7697964310646057}, {'start': 607, 'end': 616, 'text': 'cefazolin', 'label': 'Medication', 'score': 0.964414656162262}, {'start': 736, 'end': 745, 'text': 'cefazolin', 'label': 'Medication', 'score': 0.978729784488678}, {'start': 979, 'end': 989, 'text': 'chest pain', 'label': 'Symptom', 'score': 0.8688995242118835}, {'start': 1003, 'end': 1014, 'text': 'tachycardic', 'label': 'Symptom', 'score': 0.6594568490982056}, {'start': 1356, 'end': 1364, 'text': 'myalgias', 'label': 'Symptom', 'score': 0.7672026753425598}, {'start': 1366, 'end': 1377, 'text': 'joint pains', 'label': 'Symptom', 'score': 0.7221419215202332}, {'start': 1379, 'end': 1384, 'text': 'cough', 'label': 'Symptom', 'score': 0.7067722082138062}, {'start': 1386, 'end': 1396, 'text': 'hemoptysis', 'label': 'Symptom', 'score': 0.8250517249107361}, {'start': 1398, 'end': 1410, 'text': 'black\nstools', 'label': 'Symptom', 'score': 0.7306394577026367}, {'start': 1414, 'end': 1424, 'text': 'red stools', 'label': 'Symptom', 'score': 0.6696702241897583}, {'start': 1443, 'end': 1449, 'text': 'fevers
# [{'start': 171, 'end': 174, 'text': 'ASA', 'label': 'Medication', 'score': 0.8307624459266663}, {'start': 179, 'end': 186, 'text': 'Lipitor', 'label': 'Medication', 'score': 0.9633264541625977}, {'start': 191, 'end': 201, 'text': 'Lisinopril', 'label': 'Medication', 'score': 0.9560197591781616}, {'start': 206, 'end': 215, 'text': 'Terazosin', 'label': 'Medication', 'score': 0.959425687789917}, {'start': 219, 'end': 226, 'text': 'Proscar', 'label': 'Medication', 'score': 0.5896332859992981}, {'start': 230, 'end': 235, 'text': 'Zetia', 'label': 'Medication', 'score': 0.5947442054748535}, {'start': 268, 'end': 283, 'text': 'Docusate Sodium', 'label': 'Medication', 'score': 0.8458492159843445}, {'start': 380, 'end': 394, 'text': 'Ranitidine HCl', 'label': 'Medication', 'score': 0.8927072286605835}, {'start': 488, 'end': 495, 'text': 'Aspirin', 'label': 'Medication', 'score': 0.8965742588043213}, {'start': 748, 'end': 752, 'text': 'pain', 'label': 'Symptom', 'score': 0.6305288076400757}, {'start': 789, 'end': 796, 'text': 'Lipitor', 'label': 'Medication', 'score': 0.9653276205062866}, {'start': 880, 'end': 891, 'text': 'Finasteride', 'label': 'Medication', 'score': 0.9403179287910461}, {'start': 977, 'end': 986, 'text': 'Ezetimibe', 'label': 'Medication', 'score': 0.9042040109634399}, {'start': 1073, 'end': 1082, 'text': 'Ibuprofen', 'label': 'Medication', 'score': 0.908430814743042}, {'start': 1172, 'end': 1176, 'text': 'pain', 'label': 'Symptom', 'score': 0.6222216486930847}, {'start': 1213, 'end': 1223, 'text': 'Furosemide', 'label': 'Medication', 'score': 0.8603485822677612}, {'start': 1320, 'end': 1338, 'text': 'Potassium Chloride', 'label': 'Medication', 'score': 0.8062424063682556}, {'start': 1506, 'end': 1515, 'text': 'Terazosin', 'label': 'Medication', 'score': 0.9636135697364807}, {'start': 1607, 'end': 1617, 'text': 'Lisinopril', 'label': 'Medication', 'score': 0.973003089427948}, {'start': 1704, 'end': 1714, 'text': 'Carvedilol', 'label': 'Medication', 'score': 0.8578461408615112}]
# [{'start': 361, 'end': 368, 'text': 'aphasic', 'label': 'Symptom', 'score': 0.7826383113861084}, {'start': 385, 'end': 403, 'text': 'myoclonic seizures', 'label': 'Symptom', 'score': 0.9048206806182861}, {'start': 556, 'end': 564, 'text': 'dilantin', 'label': 'Medication', 'score': 0.8854084014892578}, {'start': 569, 'end': 575, 'text': 'Keppra', 'label': 'Medication', 'score': 0.9331884384155273}, {'start': 789, 'end': 798, 'text': 'meropenem', 'label': 'Medication', 'score': 0.892168402671814}, {'start': 800, 'end': 808, 'text': 'afebrile', 'label': 'Symptom', 'score': 0.6346346139907837}, {'start': 882, 'end': 891, 'text': 'meropenem', 'label': 'Medication', 'score': 0.9214101433753967}, {'start': 966, 'end': 977, 'text': 'tachycardic', 'label': 'Symptom', 'score': 0.7294655442237854}, {'start': 1151, 'end': 1160, 'text': 'diltiazem', 'label': 'Medication', 'score': 0.6392601728439331}, {'start': 1165, 'end': 1175, 'text': 'metoprolol', 'label': 'Medication', 'score': 0.5498006343841553}, {'start': 1520, 'end': 1530, 'text': 'Vicoden ES', 'label': 'Medication', 'score': 0.8043725490570068}, {'start': 1545, 'end': 1550, 'text': 'Xanax', 'label': 'Medication', 'score': 0.8458702564239502}, {'start': 1565
# [{'start': 239, 'end': 248, 'text': 'lethargic', 'label': 'Symptom', 'score': 0.7103851437568665}, {'start': 320, 'end': 328, 'text': 'lethargy', 'label': 'Symptom', 'score': 0.730961263179779}, {'start': 466, 'end': 485, 'text': 'Senna 8.6 mg Tablet', 'label': 'Medication', 'score': 0.6712512969970703}, {'start': 644, 'end': 659, 'text': 'Docusate Sodium', 'label': 'Medication', 'score': 0.8203269839286804}, {'start': 813, 'end': 820, 'text': 'Aspirin', 'label': 'Medication', 'score': 0.7673449516296387}, {'start': 876, 'end': 888, 'text': 'Thiamine HCl', 'label': 'Medication', 'score': 0.8815745115280151}, {'start': 944, 'end': 954, 'text': 'Folic Acid', 'label': 'Medication', 'score': 0.8964155316352844}, {'start': 1009, 'end': 1022, 'text': 'Levetiracetam', 'label': 'Medication', 'score': 0.7118979692459106}, {'start': 1084, 'end': 1101, 'text': 'Heparin (Porcine)', 'label': 'Medication', 'score': 0.6798256635665894}, {'start': 1173, 'end': 1222, 'text': 'Butalbital-Acetaminophen-Caff 50-325-40 mg Tablet', 'label': 'Medication', 'score': 0.5314658284187317}, {'start': 1283, 'end': 1292, 'text': 'Headaches', 'label': 'Symptom', 'score': 0.7580046057701111}, {'start': 1298, 'end': 1308, 'text': 'Nimodipine', 'label': 'Medication', 'score': 0.7870200872421265}]
# [{'start': 86, 'end': 117, 'text': 'hypercarbic\nrespiratory failure', 'label': 'Symptom', 'score': 0.7438187003135681}, {'start': 542, 'end': 561, 'text': 'Pantoprazole Sodium', 'label': 'Medication', 'score': 0.8020032048225403}, {'start': 690, 'end': 705, 'text': 'Docusate Sodium', 'label': 'Medication', 'score': 0.7324917912483215}, {'start': 786, 'end': 791, 'text': 'Senna', 'label': 'Medication', 'score': 0.6576140522956848}, {'start': 880, 'end': 894, 'text': 'Amiodarone HCl', 'label': 'Medication', 'score': 0.7083011865615845}, {'start': 969, 'end': 989, 'text': 'Atorvastatin Calcium', 'label': 'Medication', 'score': 0.6643848419189453}, {'start': 1077, 'end': 1087, 'text': 'Gabapentin', 'label': 'Medication', 'score': 0.7379617094993591}, {'start': 1164, 'end': 1188, 'text': 'Multivitamin     Capsule', 'label': 'Medication', 'score': 0.5151069164276123}, {'start': 1247, 'end': 1261, 'text': 'Cyanocobalamin', 'label': 'Medication', 'score': 0.6331789493560791}, {'start': 1341, 'end': 1356, 'text': 'Ferrous Sulfate', 'label': 'Medication', 'score': 0.6361331343650818}, {'start': 1441, 'end': 1455, 'text': 'Paroxetine HCl', 'label': 'Medication', 'score': 0.7292693257331848}, {'start': 1530, 'end': 1543, 'text': 'Bupropion HCl', 'label': 'Medication', 'score': 0.5429070591926575}, {'start': 1673, 'end': 1692, 'text': 'Doxycycline Hyclate', 'label': 'Medication', 'score': 0.7796332836151123}, {'start': 1820, 'end': 1832, 'text': 'Theophylline', 'label': '
926445007}, {'start': 1925, 'end': 1932, 'text': 'Flovent', 'label': 'Medication', 'score': 0.7216664552688599}, {'start': 1962, 'end': 1970, 'text': 'Fentanyl', 'label': 'Medication', 'score': 0.8091408014297485}, {'start': 1998, 'end': 2007, 'text': 'Lactulose', 'label': 'Medication', 'score': 0.5145736932754517}, {'start': 2012, 'end': 2020, 'text': 'Percocet', 'label': 'Medication', 'score': 0.8320091962814331}, {'start': 2029, 'end': 2035, 'text': 'Valium', 'label': 'Medication', 'score': 0.8184239268302917}, {'start': 2068, 'end': 2081, 'text': 'Acetaminophen', 'label': 'Medication', 'score': 0.6995449066162109}, {'start': 2170, 'end': 2184, 'text': 'Paroxetine HCl', 'label': 'Medication', 'score': 0.5997222661972046}, {'start': 2252, 'end': 2264, 'text': 'Lansoprazole', 'label': 'Medication', 'score': 0.6302225589752197}, {'start': 2497, 'end': 2506, 'text': 'Albuterol', 'label': 'Medication', 'score': 0.630455732345581}, {'start': 2615, 'end': 2623, 'text': 'Fentanyl', 'label': 'Medication', 'score': 0.8375515341758728}, {'start': 2720, 'end': 2725, 'text': 'Senna', 'label': 'Medication', 'score': 0.8438050746917725}, {'start': 2800, 'end': 2809, 'text': 'Bisacodyl', 'label': 'Medication', 'score': 0.5839930176734924}, {'start': 3022, 'end': 3037, 'text': 'Warfarin Sodium', 'label': 'Medication', 'score': 0.6514026522636414}, {'start': 3109, 'end': 3119, 'text': 'Olanzapine', 'label': 'Medication', 'score': 0.8017412424087524}, {'start': 3185, 'end': 3198, 'text': 'Ascorbic Acid', 'label': 'Medication', 'score': 0.6103992462158203}, {'start': 3263, 'end': 3271, 'text': 'Diazepam', 'label': 'Medication', 'score': 0.7985837459564209}, {'sta ...
# [{'start': 279, 'end': 300, 'text': 'left\nsided chest pain', 'label': 'Symptom', 'score': 0.6090747117996216}, {'start': 368, 'end': 374, 'text': 'chills', 'label': 'Symptom', 'score': 0.5742442011833191}, {'start': 394, 'end': 404, 'text': 'diaphoeris', 'label': 'Symptom', 'score': 0.5976247787475586}, {'start': 590, 'end': 596, 'text': 'ativan', 'label': 'Medication', 'score': 0.9377261996269226}, {'start': 601, 'end': 607, 'text': 'valium', 'label': 'Medication', 'score': 0.9347436428070068}, {'start': 636, 'end': 642, 'text': 'haldol', 'label': 'Medication', 'score': 0.9294898509979248}, {'start': 689, 'end': 695, 'text': 'haldol', 'label': 'Medication', 'score': 0.913909912109375}, {'start': 741, 'end': 751, 'text': 'bacitracin', 'label': 'Medication', 'score': 0.7812008857727051}, {'start': 753, 'end': 779, 'text': 'clotrimazole/betamethasone', 'label': 'Medication', 'score': 0.8412073254585266}, {'start': 781, 'end': 790, 'text': 'albuterol', 'label': 'Medication', 'score': 0.9078068137168884}, {'start': 802, 'end': 812, 'text': 'budesonide', 'label': 'Medication', 'score': 0.6988344192504883}, {'start': 831, 'end': 842, 'text': 'ipratropium', 'label': 'Medication', 'score': 0.8784182667732239}, {'start': 884, 'end': 890, 'text': 'colace', 'label': 'Medication', 'score': 0.6134719252586365}, {'start': 915
# [{'start': 358, 'end': 369, 'text': 'hypotension', 'label': 'Symptom', 'score': 0.9071083664894104}, {'start': 371, 'end': 382, 'text': 'tachycardia', 'label': 'Symptom', 'score': 0.9183251261711121}, {'start': 387, 'end': 390, 'text': 'UTI', 'label': 'Symptom', 'score': 0.609150767326355}, {'start': 591, 'end': 599, 'text': 'fentanyl', 'label': 'Medication', 'score': 0.9299495220184326}, {'start': 611, 'end': 617, 'text': 'haldol', 'label': 'Medication', 'score': 0.9557053446769714}, {'start': 623, 'end': 629, 'text': 'lantus', 'label': 'Medication', 'score': 0.8383014798164368}, {'start': 641, 'end': 649, 'text': 'atrovent', 'label': 'Medication', 'score': 0.7961654663085938}, {'start': 654, 'end': 662, 'text': 'prevacid', 'label': 'Medication', 'score': 0.8277172446250916}, {'start': 669, 'end': 672, 'text': 'ASA', 'label': 'Medication', 'score': 0.65192049741745}, {'start': 711, 'end': 716, 'text': 'paxil', 'label': 'Medication', 'score': 0.8842078447341919}, {'start': 744, 'end': 756, 'text': 'levalbuterol', 'label': 'Medication', 'score': 0.5156149864196777}, {'start': 757, 'end': 765, 'text': 'cardizem', 'label': 'Medication', 'score': 0.6399113535881042}, {'start': 773, 'end': 781, 'text': 'coumadin', 'label': 'Medication', 'score': 0.9242823123931885}, {'start': 789, 'end': 795, 'text': 'haldol', 'label': 'Medication', 'score': 0.9315229058265686}, {'start': 810, 'end': 816, 'text': 'Haldol', 'label': 'Medication', 'score': 0.9547142386436462}, {'start': 852, 'end': 860, 'text': 'Fentanyl', 'label': 'Medication', 'score': 0.9607527256011963}, {'start': 957, 'end': 964, 'text': 'Aspirin', 'label': 'Medication', 'score': 0.7985662817955017}, {'start': 1033, 'end': 1047, 'text': 'Paroxetine HCl', 'label': 'Medication', 'score': 0.8427162170410156}, {'start': 1115, 'end': 1132, 'text': 'Zolpidem Tartrate', 'label': 'Medication', 'score': 0.8037923574447632}, {'start': 1201, 'end': 1212, 'text': 'Haloperidol', 'label': 'Medication', 'score': 0.898969292640686}, {'start': 1281, 'end': 1292, 'text': 'Haloperidol', 'label': 'Medication', 'score': 0.9305352568626404}, {'start': 1363, 'end': 1374, 'text': 'Haloperidol', 'label': 'Medication', 'score': 0.9272210001945496}, {'start': 1457, 'end': 1469, 'text': 'Zinc Sulfate', 'label': 'Medication', 'score': 0.677487850189209}, {'start': 1718, 'end': 1733, 'text': 'Docusate Sodium', 'label': 'Medication', 'score': 0.7360712885856628}, {'start': 1811, 'end': 1824, 'text': 'Ascorbic Acid', 'label': 'Medication', 'score': 0.7320267558097839}, {'start': 1900, 'end': 1919, 'text': 'Ipratropium Bromide', 'label': 'Medication', 'score': 0.7403835654258728}, {'start': 2012, 'end': 2021, 'text': 'Albuterol', 'label': 'Medication', 'score': 0.8539741635322571}, {'start': 2111, 'end': 2133, 'text': 'Fluticasone Propionate', 'label': 'Medication', 'score': 0.7043132781982422}, {'start': 2240, 'end': 2252, 'text': 'Lansoprazole', 'label': 'Medication', 'score': 0.7751660346984863}, {'start': 2369, 'end': 2385, 'text': 'Morphine Sulfate', 'label': 'Medication', 'score': 0.9185189008712769}, {'start': 2488, 'end': 2497, 'text': 'Bisacodyl', 'label': 'Medication', 'score': 0.748023509979248}, {'start': 2623, 'end': 2628, 'text': 'Senna', 'label': 'Medication', 'score': 0.8416580557823181}, {'start': 2704, 'end': 2718, '
, 'end': 3208, 'text': 'Humulin SS', 'label': 'Medication', 'score': 0.8561460375785828}, {'start': 3213, 'end': 3221, 'text': 'Atrovent', 'label': 'Medication', 'score': 0.8131248354911804}, {'start': 3239, 'end': 3246, 'text': 'Xopenex', 'label': 'Medication', 'score': 0.8931642770767212}, {'start': 3267, 'end': 3274, 'text': 'Tylenol', 'label': 'Medication', 'score': 0.7645822167396545}, {'start': 3294, 'end': 3300, 'text': 'Haldol', 'label': 'Medication', 'score': 0.9276203513145447}, {'start': 3350, 'end': 3360, 'text': 'Amiodarone', 'label': 'Medication', 'score': 0.6795169115066528}, {'start': 3402, 'end': 3424, 'text': 'Fluticasone Propionate', 'label': 'Medication', 'score': 0.5490638613700867}, {'start': 3715, 'end': 3730, 'text': 'Docusate Sodium', 'label': 'Medication', 'score': 0.6684331893920898}, {'start': 3817, 'end': 3830, 'text': 'Acetaminophen', 'label': 'Medication', 'score': 0.7339929938316345}, {'start': 3919, 'end': 3928, 'text': 'Bisacodyl', 'label': 'Medication', 'score': 0.6331501007080078}, {'start': 4053, 'end': 4067, 'text': 'Paroxetine HCl', 'label': 'Medication', 'score': 0.7204033136367798}, {'start': 4135, 'end': 4142, 'text': 'Aspirin', 'label': 'Medication', 'score': 0.7840251922607422}, {'start': 4211, 'end': 4223, 'text': 'Lansoprazole', 'label': 'Medication', 'score': 0.685858964920044}, {'start': 4340, 'end': 4350, 'text': 'Amiodarone', 'label': 'Medication', 'score': 0.61900448799133 ...
# [{'start': 1094, 'end': 1108, 'text': 'abdominal pain', 'label': 'Symptom', 'score': 0.8685462474822998}, {'start': 1115, 'end': 1123, 'text': 'diarrhea', 'label': 'Symptom', 'score': 0.9201914668083191}, {'start': 1125, 'end': 1137, 'text': 'hematochezia', 'label': 'Symptom', 'score': 0.9392784833908081}, {'start': 1142, 'end': 1148, 'text': 'melena', 'label': 'Symptom', 'score': 0.8790809512138367}, {'start': 1168, 'end': 1174, 'text': 'NSAIDs', 'label': 'Medication', 'score': 0.8405489325523376}, {'start': 1178, 'end': 1181, 'text': 'ASA', 'label': 'Medication', 'score': 0.9023873209953308}, {'start': 1276, 'end': 1279, 'text': 'PPI', 'label': 'Medication', 'score': 0.8240066170692444}, {'start': 1419, 'end': 1429, 'text': 'Citalopram', 'label': 'Medication', 'score': 0.9564098715782166}, {'start': 1442, 'end': 1451, 'text': 'Donepezil', 'label': 'Medication', 'score': 0.9383302927017212}, {'start': 1492, 'end': 1502, 'text': 'Citalopram', 'label': 'Medication', 'score': 0.9617112278938293}, {'start': 1554, 'end': 1563, 'text': 'Donepezil', 'label': 'Medication', 'score': 0.9543006420135498}, {'start': 1615, 'end': 1625, 'text': 'Omeprazole', 'label': 'Medication', 'score': 0.843089759349823}, {'start': 1937, 'end': 1947, 'text': 'omeprazole', 'label': 'Medication', 'score': 0.7170105576515198}]
# [{'start': 224, 'end': 229, 'text': 'fever', 'label': 'Symptom', 'score': 0.5127836465835571}, {'start': 258, 'end': 267, 'text': 'albuterol', 'label': 'Medication', 'score': 0.8247710466384888}, {'start': 298, 'end': 301, 'text': 'SOB', 'label': 'Symptom', 'score': 0.6351366639137268}, {'start': 303, 'end': 314, 'text': 'sore throat', 'label': 'Symptom', 'score': 0.7137649059295654}, {'start': 316, 'end': 326, 'text': 'congestion', 'label': 'Symptom', 'score': 0.8421002626419067}, {'start': 328, 'end': 338, 'text': 'chest pain', 'label': 'Symptom', 'score': 0.898963987827301}, {'start': 340, 'end': 355, 'text': 'lightheadedness', 'label': 'Symptom', 'score': 0.6698488593101501}, {'start': 357, 'end': 365, 'text': 'headache', 'label': 'Symptom', 'score': 0.7283831238746643}, {'start': 367, 'end': 384, 'text': 'dysuria/frequency', 'label': 'Symptom', 'score': 0.7282673716545105}, {'start': 386, 'end': 400, 'text': 'abdominal pain', 'label': 'Symptom', 'score': 0.9200307130813599}, {'start': 402, 'end': 423, 'text': 'diarrhea/constipation', 'label': 'Symptom', 'score': 0.8759292364120483}, {'start': 801, 'end': 812, 'text': 'ceftriaxone', 'label': 'Medication', 'score': 0.6019989848136902}, {'start': 1704, 'end': 1714, 'text': 'congestion', 'label': 'Symptom', 'score': 0.8552402853965759}, {'start': 1723, 'end': 1742, 'text': 'shortness of breath', 'label': 'Symptom', 'score': 0.6205770969390869}, {'start': 1751, 'end': 1761, 'text': 'chest pain', 'label': 'Symptom', 'score': 0.8569864630699158}, {'start': 1841, 'end': 1855, 'text': 'abdominal pain', 'label': 'Symptom', 'score': 0.9258857369422913}, {'start': 1973, 'end': 1984, 'text': 'calcium + D', 'label': 'Medication', 'score': 0.5847676396369934}, {'start': 1985, 'end': 1994, 'text': 'enalapril', 'label': 'Medication', 'score': 0.6140184998512268}, {'start': 2005, 'end': 2015, 'text': 'isosorbide', 'label': 'Medication', 'score': 0.7918244004249573}, {'start': 2026, 'end': 2031, 'text': 'lasix', 'label': 'Medication', 'score': 0.780200719833374}, {'start': 2042, 'end': 2056, 'text': 'spironolactone', 'label': 'Medication', 'score': 0.8252168297767639}, {'start': 2079, 'end': 2086, 'text': 'ecotrin', 'label': 'Medication', 'score': 0.8372986316680908}, {'start': 2098, 'end': 2104, 'text': 'flomax', 'label': 'Medication', 'score': 0.6406610608100891}, {'start': 2116, 'end': 2124, 'text': 'coumadin', 'label': 'Medication', 'score': 0.930600106716156}, {'start': 2134, 'end': 2144, 'text': 'amlodipine', 'label': 'Medication', 'score': 0.8465479612350464}, {'start': 2156, 'end': 2167, 'text': 'pravastatin', 'label': 'Medication', 'score': 0.7238348722457886}, {'start': 2178, 'end': 2189, 'text': 'finasteride', 'label': 'Medication', 'score': 0.9017755389213562}, {'start': 2331, 'end': 2348, 'text': 'Enalapril Maleate', 'label': 'Medication', 'score': 0.6158984303474426}, {'start': 2401, 'end': 2411, 'text': 'Furosemide', 'label': 'Medication', 'score': 0.678867518901825}, {'start': 2467, 'end': 2474, 'text': 'Ecotrin', 'label': 'Medication', 'score': 0.8789220452308655}, {'start': 2575, 'end': 2585, 'text': 'Tamsulosin', 'label': 'Medication', 'score': 0.6639084219932556}, {'start': 2687, 'end': 2695, 'text': 'Coumadin', 'label': 'Medication', 'score': 0.875268280506134}, {'start': 2779, 'end': 2787, 'text': 'Coumadin', 'label': 'Medication', 'score': 0.9170505404472351}, {'start': 2845, 'end': 2855, 'text': 'Amlodipine', 'label': 'Medication', 'score': 0.875831663608551}, {'start': 2911, 'end': 2922, 'text': 'Pravastatin', 'label': 'Medication', 'score': 0.7835515141487122}, {'start': 2978, 'end': 2989, 'text': 'Finasteride', 'label': 'Medication', 'score': 0.9236464500427246}, {'start': 3107, 'end': 3117, 'text': 'Gabapentin', 'label': 'Medication', 'score': 0.5272104740142822}, {'start': 3215, 'end': 3226, 'text': 'Cefpodoxime', 'label': 'Medication', 'score': 0.6377750039100647}, {'start': 3362, 'end': 3373, 'text': 'Fluticasone', 'label': 'Medication', 'score': 0.64022517204 ...
# [{'start': 109, 'end': 112, 'text': 'SOB', 'label': 'Symptom', 'score': 0.7378966212272644}, {'start': 117, 'end': 120, 'text': 'DOE', 'label': 'Symptom', 'score': 0.6462059617042542}, {'start': 362, 'end': 365, 'text': 'DOE', 'label': 'Symptom', 'score': 0.5242690443992615}, {'start': 391, 'end': 410, 'text': 'Shortness of breath', 'label': 'Symptom', 'score': 0.5468732714653015}, {'start': 465, 'end': 475, 'text': 'chest pain', 'label': 'Symptom', 'score': 0.8718517422676086}, {'start': 487, 'end': 515, 'text': 'paroxysmal\nnocturnal dyspnea', 'label': 'Symptom', 'score': 0.8384909629821777}, {'start': 567, 'end': 576, 'text': 'orthopnea', 'label': 'Symptom', 'score': 0.7779995203018188}, {'start': 637, 'end': 643, 'text': 'fevers', 'label': 'Symptom', 'score': 0.6198306083679199}, {'start': 645, 'end': 650, 'text': 'cough', 'label': 'Symptom', 'score': 0.7104960680007935}, {'start': 652, 'end': 662, 'text': 'rhinorrhea', 'label': 'Symptom', 'score': 0.7874888777732849}, {'start': 664, 'end': 674, 'text': 'chest pain', 'label': 'Symptom', 'score': 0.9088571667671204}, {'start': 676, 'end': 684, 'text': 'diarrhea', 'label': 'Symptom', 'score': 0.8193310499191284}, {'start': 689, 'end': 696, 'text': 'dysuria', 'label': 'Symptom', 'score': 0.7505069375038147}, {'start': 706, 'end': 727, 'text': 'lower extremity edema', 'label': 'Symptom', 'score': 0.6196376085281372}, {'start': 737, 'end': 749, 'text': 'palpitations', 'label': 'Symptom', 'score': 0.793702244758606}, {'start': 952, 'end': 958, 'text': 'fluvax', 'label': 'Medication', 'score': 0.5413199663162231}, {'start': 962, 'end': 971, 'text': 'pneumovax', 'label': 'Medication', 'score': 0.6793786883354187}, {'start': 1226, 'end': 1235, 'text': 'Ascriptin', 'label': 'Medication', 'score': 0.9808279871940613}, {'start': 1265, 'end': 1273, 'text': 'caltrate', 'label': 'Medication', 'score': 0.9687245488166809}, {'start': 1294, 'end': 1304, 'text': 'Metoprolol', 'label': 'Medication', 'score': 0.9788989424705505}, {'start': 1339, 'end': 1346, 'text': 'Fosomax', 'label': 'Medication', 'score': 0.9797806739807129}, {'start': 1363, 'end': 1368, 'text': 'zocor', 'label': 'Medication', 'score': 0.9580678343772888}, {'start': 1389, 'end': 1392, 'text': 'MVT', 'label': 'Medication', 'score': 0.9097445607185364}]
# [{'start': 316, 'end': 325, 'text': 'tachypnea', 'label': 'Symptom', 'score': 0.7244182229042053}, {'start': 438, 'end': 441, 'text': 'SOB', 'label': 'Symptom', 'score': 0.7208424210548401}, {'start': 458, 'end': 466, 'text': 'Morphine', 'label': 'Medication', 'score': 0.8906477093696594}, {'start': 690, 'end': 696, 'text': 'Narcan', 'label': 'Medication', 'score': 0.8748685717582703}, {'start': 901, 'end': 916, 'text': 'succinylcholine', 'label': 'Medication', 'score': 0.8786066770553589}, {'start': 921, 'end': 930, 'text': 'etomidate', 'label': 'Medication', 'score': 0.8608183860778809}, {'start': 956, 'end': 962, 'text': 'versed', 'label': 'Medication', 'score': 0.8908329010009766}, {'start': 1004, 'end': 1010, 'text': 'versed', 'label': 'Medication', 'score': 0.8173389434814453}, {'start': 1076, 'end': 1084, 'text': 'levophed', 'label': 'Medication', 'score': 0.8906958103179932}, {'start': 1187, 'end': 1199, 'text': 'phentolamine', 'label': 'Medication', 'score': 0.8463177680969238}, {'start': 1296, 'end': 1304, 'text': 'dopamine', 'label': 'Medication', 'score': 0.7958754897117615}, {'start': 1425, 'end': 1434, 'text': 'lidocaine', 'label': 'Medication', 'score': 0.868206799030304}, {'start': 1439, 'end': 1448, 'text': 'magnesium', 'label': 'Medication', 'score': 0.6778480410575867}, {'start': 1463, 'end': 1471, 'text': 'levophed', 'label': 'Medication', 'score': 0.8738979697227478}, {'start': 1552, 'end': 1563, 'text': 'ceftriaxone', 'label': 'Medication', 'score': 0.6462386250495911}, {'start': 1565, 'end': 1575, 'text': 'Vancomycin', 'label': 'Medication', 'score': 0.7226176857948303}, {'start': 1577, 'end': 1583, 'text': 'Flagyl', 'label': 'Medication', 'score': 0.8022551536560059}, {'start': 1702, 'end': 1705, 'text': 'SOB', 'label': 'Symptom', 'score': 0.6134145855903625}, {'start': 2023, 'end': 2026, 'text': 'ASA', 'label': 'Medication', 'score': 0.875191330909729}, {'start': 2027, 'end': 2040, 'text': 'Levothyroxine', 'label': 'Medication', 'score': 0.9103241562843323}, {'start': 2054, 'end': 2065, 'text': 'peptobismol', 'label': 'Medication', 'score': 0.7542635798454285}, {'start': 2066, 'end': 2073, 'text': 'tylenol', 'label': 'Medication', 'score': 0.9188511967658997}, {'start': 2074, 'end': 2080, 'text': 'nexium', 'label': 'Medication', 'score': 0.7864432334899902}, {'start': 2081, 'end': 2085, 'text': 'MSO4', 'label': 'Medication', 'score': 0.5336273908615112}, {'start': 2099, 'end': 2106, 'text': 'duonebs', 'label': 'Medication', 'score': 0.7161396741867065}, {'start': 2107, 'end': 2118, 'text': 'pantop\ndilt', 'label': 'Medication', 'score': 0.5387407541275024}, {'start': 2127, 'end': 2135, 'text': 'metop xl', 'label': 'Medication', 'score': 0.6346782445907593}, {'start': 2221, 'end': 2234, 'text': 'Acetaminophen', 'label': 'Medication', 'score': 0.8392758965492249}, {'start': 2310, 'end': 2325, 'text': 'Docusate Sodium', 'label': 'Medication', 'score': 0.8767561316490173}, {'start': 2387, 'end': 2394, 'text': 'Aspirin', 'label': 'Medication', 'score': 0.8699104189872742}, {'start': 2450, 'end': 2463, 'text': 'Levothyroxine', 'label': 'Medication', 'score': 0.9271243214607239}, {'start': 2520, 'end': 2539, 'text': 'Ipratropium Bromide', 'label': 'Medication', 'score': 0.811282753944397}, {'start': 2635, 'end': 2653, 'text': 'Miconazole Nitrate', 'label': 'Medication', 'score': 0.6847767233848572}, {'start': 2739, 'end': 2748, 'text': 'Albuterol', 'label': 'Medication', 'score': 0.8986064195632935}, {'start': 2844, 'end': 2859, 'text': 'Fludrocortisone', 'label': 'Medication', 'score': 0.8076364398002625}, {'start': 2926, 'end': 2954, 'text': 'Hydrocortisone Sod Succinate', 'label': 'Medication', 'score': 0.7348054647445679}, {'start': 3048, 'end': 3061, 'text': 'Diltiazem HCl', 'label': 'Medication', 'score': 0.8455262780189514}, {'start': 3123, 'end': 3144, 'text': 'Insulin Regular Human', 'label': 'Medication', 'score': 0.6588034629821777}, {'start': 3498, 'end': 3515, 'text': 'Heparin (Porcine)', 'label' ...
# ...
# [{'start': 482, 'end': 497, 'text': 'demand ischemia', 'label': 'Symptom', 'score': 0.620700478553772}, {'start': 684, 'end': 694, 'text': 'Vancomycin', 'label': 'Medication', 'score': 0.9614743590354919}, {'start': 699, 'end': 711, 'text': 'levofloxacin', 'label': 'Medication', 'score': 0.9170473217964172}, {'start': 884, 'end': 891, 'text': 'Zyprexa', 'label': 'Medication', 'score': 0.9322813749313354}, {'start': 1030, 'end': 1036, 'text': 'Plavix', 'label': 'Medication', 'score': 0.9216381907463074}, {'start': 1078, 'end': 1085, 'text': 'Aspirin', 'label': 'Medication', 'score': 0.7572304606437683}, {'start': 1245, 'end': 1256, 'text': 'Clopidogrel', 'label': 'Medication', 'score': 0.743355929851532}, {'start': 1343, 'end': 1362, 'text': 'Metoprolol Tartrate', 'label': 'Medication', 'score': 0.673831045627594}, {'start': 1423, 'end': 1432, 'text': 'Valsartan', 'label': 'Medication', 'score': 0.5329638719558716}, {'start': 1488, 'end': 1498, 'text': 'Amlodipine', 'label': 'Medication', 'score': 0.7834109663963318}, {'start': 1678, 'end': 1690, 'text': 'Fluocinonide', 'label': 'Medication', 'score': 0.7090954780578613}, {'start': 1776, 'end': 1789, 'text': 'Acetaminophen', 'label': 'Medication', 'score': 0.9149907827377319}, {'start': 1989, 'end': 2004, 'text': 'Ferrous Sulfate', 'label': 'Medication', 'score': 0.7391579747200012}, {'start': 2074, 'end': 2109, 'text': 'Carbidopa-Levodopa 25-100 mg Tablet', 'label': 'Medication', 'score': 0.5637943744659424}, {'start': 2158, 'end': 2172, 'text': 'Ranitidine HCl', 'label': 'Medication', 'score': 0.6990711092948914}, {'start': 2235, 'end': 2254, 'text': 'Multivitamin Tablet', 'label': 'Medication', 'score': 0.6660659909248352}, {'start': 2297, 'end': 2321, 'text': 'Polyethylene Glycol 3350', 'label': 'Medication', 'score': 0.563926637172699}, {'start': 2411, 'end': 2422, 'text': 'Simvastatin', 'label': 'Medication', 'score': 0.7972996234893799}, {'start': 2478, 'end': 2487, 'text': 'Lidocaine', 'label': 'Medication', 'score': 0.8435469269752502}, {'start': 2598, 'end': 2609, 'text': 'Allopurinol', 'label': 'Medication', 'score': 0.8763473629951477}, {'start': 2663, 'end': 2685, 'text': 'Isosorbide Mononitrate', 'label': 'Medication', 'score': 0.6811121106147766}, {'start': 2736, 'end': 2744, 'text': 'Oxazepam', 'label': 'Medication', 'score': 0.791029691696167}, {'start': 2796, 'end': 2806, 'text': 'Vancomycin', 'label': 'Medication', 'score': 0.9166035652160645}, {'start': 2961, 'end': 2978, 'text': 'albuterol sulfate', 'label': 'Medication', 'score': 0.8047325015068054}, {'start': 3100, 'end': 3111, 'text': 'brimonidine', 'label': 'Medication', 'score': 0.7838854789733887}, {'start': 3181, 'end': 3196, 'text': 'timolol maleate', 'label': 'Medication', 'score': 0.7154216766357422}, {'start': 3275, 'end': 3284, 'text': 'bisacodyl', 'label': 'Medication', 'score': 0.8009299039840698}, {'start': 3380, 'end': 3393, 'text': 'lidocaine HCl', 'label': 'Medication', 'score': 0.693117618560791}, {'start': 3482, 'end': 3488, 'text': 'phenol', 'label': 'Medication', 'score': 0.6263875961303711}, {'start': 3591, 'end': 3601, 'text': 'olanzapine', 'label': 'Medication', 'score': 0.8233564496040344}, {'start': 3713, 'end': 3726, 'text': 'acetaminophen', 'label': 'Medication', 'score': 0.9281088709831238}, {'start': 3803, 'end': 3823, 'text': 'morphine concentrate', 'label': 'Medication', 'score': 0.6890856623649597}, {'start': 3898, 'end': 3909, 'text': 'allopurinol', 'label': 'Medication', 'score': 0.8144456744194031}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1b9b00892548> in <cell line: 0>()
#      11 symptoms, medications = ([] for i in range(2))
#      12 for input_text in notes_sections_df['text']:
# ---> 13   entities = model.predict_entities(input_text, labels, threshold=0.5)
#      14
#      15   print(entities)
#
# /usr/local/lib/python3.11/dist-packages/gliner/model.py in predict_entities(self, text, labels, flat_ner, threshold, multi_label)
#     240             The list of entity predictions.
#     241         """
# --> 242         return self.batch_predict_entities(
#     243             [text],
#     244             labels,
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/gliner/model.py in batch_predict_entities(self, texts, labels, flat_ner, threshold, multi_label)
#     268         model_input, raw_batch = self.prepare_model_inputs(texts, labels)
#     269
# --> 270         model_output = self.model(**model_input)[0]
#     271
#     272         if not isinstance(model_output, torch.Tensor):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/gliner/modeling/base.py in forward(self, input_ids, attention_mask, labels_embeddings, labels_input_ids, labels_attention_mask, words_embedding, mask, prompts_embedding, prompts_embedding_mask, words_mask, text_lengths, span_idx, span_mask, labels, **kwargs)
#     231                 ):
#     232
# --> 233         prompts_embedding, prompts_embedding_mask, words_embedding, mask = self.get_representations(input_ids, attention_mask,
#     234                                                                                 labels_embeddings, labels_input_ids, labels_attention_mask,
#     235                                                                                                                     text_lengths, words_mask)
#
# /usr/local/lib/python3.11/dist-packages/gliner/modeling/base.py in get_representations(self, input_ids, attention_mask, labels_embeddings, labels_input_ids, labels_attention_mask, text_lengths, words_mask, **kwargs)
#     180             )
#     181         else:
# --> 182             prompts_embedding, prompts_embedding_mask, words_embedding, mask = self.get_uni_representations(
#     183                                     input_ids, attention_mask, text_lengths, words_mask, **kwargs
#     184             )
#
# /usr/local/lib/python3.11/dist-packages/gliner/modeling/base.py in get_uni_representations(self, input_ids, attention_mask, text_lengths, words_mask, **kwargs)
#     124                 **kwargs):
#     125
# --> 126         token_embeds = self.token_rep_layer(input_ids, attention_mask, **kwargs)
#     127
#     128         prompts_embedding, prompts_embedding_mask, words_embedding, mask = self._extract_prompt_features_and_word_embeddings(token_embeds, input_ids, attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/gliner/modeling/encoder.py in forward(self, *args, **kwargs)
#     134
#     135     def forward(self, *args, **kwargs) -> torch.Tensor:
# --> 136         token_embeddings = self.encode_text(*args, **kwargs)
#     137         return token_embeddings
#     138
#
# /usr/local/lib/python3.11/dist-packages/gliner/modeling/encoder.py in encode_text(self, input_ids, attention_mask, *args, **kwargs)
#     128
#     129     def encode_text(self, input_ids, attention_mask, *args, **kwargs):
# --> 130         token_embeddings = self.bert_layer(input_ids, attention_mask, *args, **kwargs)
#     131         if hasattr(self, "projection"):
#     132             token_embeddings = self.projection(token_embeddings)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/gliner/modeling/encoder.py in forward(self, *args, **kwargs)
#      98         else:
#      99             output_hidden_states = False
# --> 100         output = self.model(*args, output_hidden_states = output_hidden_states,
#     101                                             return_dict = True,  **kwargs)
#     102         if self.config.fuse_layers:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/deberta_v2/modeling_deberta_v2.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     868         )
#     869
# --> 870         encoder_outputs = self.encoder(
#     871             embedding_output,
#     872             attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/deberta_v2/modeling_deberta_v2.py in forward(self, hidden_states, attention_mask, output_hidden_states, output_attentions, query_states, relative_pos, return_dict)
#     672                 )
#     673             else:
# --> 674                 output_states, attn_weights = layer_module(
#     675                     next_kv,
#     676                     attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/deberta_v2/modeling_deberta_v2.py in forward(self, hidden_states, attention_mask, query_states, relative_pos, rel_embeddings, output_attentions)
#     440         output_attentions: bool = False,
#     441     ) -> Tuple[torch.Tensor, Optional[torch.Tensor]]:
# --> 442         attention_output, att_matrix = self.attention(
#     443             hidden_states,
#     444             attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/deberta_v2/modeling_deberta_v2.py in forward(self, hidden_states, attention_mask, output_attentions, query_states, relative_pos, rel_embeddings)
#     373         rel_embeddings=None,
#     374     ) -> Tuple[torch.Tensor, Optional[torch.Tensor]]:
# --> 375         self_output, att_matrix = self.self(
#     376             hidden_states,
#     377             attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/deberta_v2/modeling_deberta_v2.py in forward(self, hidden_states, attention_mask, output_attentions, query_states, relative_pos, rel_embeddings)
#     261         attention_scores = attention_scores
#     262         attention_scores = attention_scores.view(
# --> 263             -1, self.num_attention_heads, attention_scores.size(-2), attention_scores.size(-1)
#     264         )
#     265
#
# KeyboardInterrupt:
